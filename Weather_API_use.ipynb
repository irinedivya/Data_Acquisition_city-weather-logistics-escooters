# %% [markdown]
# # Adding Weather Data to MySQL using API's
#
# In this document I use OpenWeather to get weather data as well as better latitudes and longitudes that will need to used to access the weather information

# %%
import pandas as pd
import requests
from datetime import datetime
from dotenv import load_dotenv
import os
load_dotenv()
from pytz import timezone

# %%
# Set-up API Request info pull

city = 'Berlin'
latitude = 52.51
longitude = 13.38
API_key = "YOUR API KEY"
URL = 'https://api.openweathermap.org/data/2.5/forecast?'
params = {'lat' : latitude, 'lon': longitude, 'appid': API_key, 'units': 'metric', 'cnt':'3'}
weather = requests.get(url = URL, params=params)

# %%
# look through weather information that you want to keep
weather_jscon = weather.json()
weather_jscon
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 3,
#  'list': [{'dt': 1763985600,
#    'main': {'temp': 1.33,
#     'feels_like': -1.67,
#     'temp_min': 1.33,
#     'temp_max': 2.28,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 993,
#     'humidity': 88,
#     'temp_kf': -0.95},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.73, 'deg': 206, 'gust': 6.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-11-24 12:00:00'},
#   {'dt': 1763996400,
#    'main': {'temp': 1.01,
#     'feels_like': -1.86,
#     'temp_min': 1.01,
#     'temp_max': 1.08,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 993,
#     'humidity': 92,
#     'temp_kf': -0.07},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 65},
# ...

# %%
weather_jscon['list'][0]['main']['temp']
# Out:
# 1.33

# %%
# testing loops to get information
main_temps = [{
        "temp": item.get("main", {}).get("temp"),
        "feels_like": item.get("main", {}).get("feels_like"),
        "humidity": item.get("main", {}).get("humidity")
    }
    for item in weather_jscon.get("list", [])
]

# %%
Berlin_Temperatures = pd.DataFrame(main_temps)
Berlin_Temperatures
# Out:
#    temp  feels_like  humidity
# 0  1.33       -1.67        88
# 1  1.01       -1.86        92
# 2  0.68       -2.76        96

# %% [markdown]
# Need to use latitude and longitude as decimals to pull informatino from OPENWeather luckily OPEN Weather Can help us out with that. But we do need the two letter Country code.
#
#
#
# In MySQL
# USE Europeancities;
#
# UPDATE city_name
# SET country_code = CASE
#     WHEN city = 'Paris' THEN 'FR'
#     WHEN city = 'Brussels' THEN 'BE'
#     ELSE 'DE'
# END
# WHERE city_name_id > 0;

# %%
# Pulling new latitude and longitude

geo_base_url = 'http://api.openweathermap.org/geo/1.0/direct?'
name = 'Berlin'
code = 'de'
API_key = "YOUR API KEY"
params = params = {
    "q": f"{name},{code}",
    "limit": 1,
    "appid": API_key
}

city_lat_lon = requests.get(geo_base_url, params =params)
city_latlong = city_lat_lon.json()
city_latlong
# Out:
# [{'name': 'Berlin',
#   'local_names': {'yi': 'בערלין',
#    'co': 'Berlinu',
#    'hi': 'बर्लिन',
#    'ky': 'Берлин',
#    'az': 'Berlin',
#    'bo': 'པེ་ལིང་',
#    'gd': 'Berlin',
#    'sq': 'Berlini',
#    'et': 'Berliin',
#    'bs': 'Berlin',
#    'ia': 'Berlin',
#    'el': 'Βερολίνο',
#    'tt': 'Берлин',
#    'kv': 'Берлин',
#    'ty': 'Berlin',
#    'se': 'Berlin',
#    'mg': 'Berlin',
#    'uz': 'Berlin',
#    'mi': 'Pearīni',
#    'ca': 'Berlín',
#    'ru': 'Берлин',
#    'sl': 'Berlin',
#    'ln': 'Berlin',
#    'mk': 'Берлин',
#    'am': 'በርሊን',
#    'hr': 'Berlin',
#    'fa': 'برلین',
#    'rm': 'Berlin',
#    'jv': 'Berlin',
#    'ml': 'ബെര്\u200dലിന്',
#    'lt': 'Berlynas',
#    'nl': 'Berlijn',
#    'qu': 'Berlin',
#    'ht': 'Bèlen',
#    'kn': 'ಬೆರ್ಲಿನ್',
#    'de': 'Berlin',
#    'ar': 'برلين',
#    'vi': 'Berlin',
#    'sc': 'Berlinu',
#    'gv': 'Berleen',
#    'lg': 'Berlin',
#    'ie': 'Berlin',
#    'sr': 'Берлин',
#    'na': 'Berlin',
#    'ba': 'Берлин',
# ...

# %%
cities_from_sql = pd.read_sql("city_name", con=connection_string) # retriving information from SQL
cities_from_sql

city_info = cities_from_sql.merge(cities_info_mysql, left_on ='city_name_id', right_on ='city_name_id', how = 'inner').drop(columns=[
    'city',
    ]).copy()
city_info = city_info.drop(columns = ['country_code_x', 'lat_y', 'lon_y']).copy()
city_info
# want to keep the decimal result for lat and lon

city_info = city_info.rename(columns={
    'city_name_id': 'city_name_id',
    'lat_x': 'la',
    'lon_x': 'lon',
    'city_info_id': 'city_info_id',
    'country_code_y': 'country_code'
})

city_info

city_info_df = city_info

# %%
city_info_df = city_info
city_info_df

# %% [markdown]
# Send updated table to MySQL using
#
# USE Europeancities;
# DROP Table city_info
#
# CREATE Table city_info (
# 	city_info_id INT AUTO_INCREMENT,
#     city_name_id INT NOT NULL,
#     country_code VARCHAR (50)NOT NULL,
#     lat	FLOAT  NOT NULL,
# 	lon FLOAT  NOT NULL,
#     country_code VARCHAR (50)NOT NULL,
# 	PRIMARY KEY (city_info_id), -- primary key to id each airport
# 	FOREIGN KEY (city_name_id) REFERENCES city_name(city_name_id) -- for
#  );

# %%
# Send new table to MySQL
schema = "Europeancities"
host = "127.0.0.1"
user = "root"
password = "password"
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

city_info_df.to_sql('city_info',
                  if_exists='append',
                  con=connection_string,
                  index=False)

# %% [markdown]
# Now we can get weather data and set it up

# %%
# created a loop to pull information

 for index, row in cities_from_sql.iterrows():
        latitude = row['lat']
        longitude = row['lon']
        Weather_information['city_id'].append(row['city_name_id'])

        API_key = "YOUR API KEY"
        URL = 'https://api.openweathermap.org/data/2.5/forecast?'
        params = {'lat' : latitude, 'lon': longitude, 'appid': API_key, 'units':'metric', 'cnt':'1'}
        weather = requests.get(url = URL, params=params)
        weather_jscon = weather.json()

        dt_info = weather_jscon['list'][0]['dt_txt']
        current_temp = weather_jscon['list'][0]['main']['temp']
        max_temp = weather_jscon['list'][0].get('temp_max')
        min_temp = weather_jscon['list'][0]['main']['temp_min']
        humitidy = weather_jscon['list'][0]['main']['humidity']
        sky_description = weather_jscon['list'][0]['weather'][0]['description']
        wind_speed = weather_jscon['list'][0]['wind']['speed']
        visibility = weather_jscon['list'][0]['visibility']
        sunrise = weather_jscon['city'].get('sunrise')
        sunset = weather_jscon['city'].get('sunset')

        Weather_information['date_and_times'].append(dt_info)
        Weather_information['current_temps'].append(current_temp)
        Weather_information['max_temps'].append(max_temp)
        Weather_information['min_temps'].append(min_temp)
        Weather_information['humidties'].append(humitidy)
        Weather_information['sky_descriptions'].append(sky_description)
        Weather_information['wind_speeds'].append( wind_speed)
        Weather_information['visibilities'].append(visibility)
        Weather_information['sunsets_UTC'].append(sunset)
        Weather_information['sunrises_UTC'].append(sunrise)
    return pd.DataFrame

# %%
# Weather_dataframe = pd.DataFrame(Weather_information)
#Weather_dataframe

# %% [markdown]
# Send Weather date to MySQL
#
# USE Europeancities;
#
# CREATE TABLE weather (
#     weather_id INT AUTO_INCREMENT,
#     city_name_id (50)NOT NULL,
#     date_and_times DATETIME NOT NULL,
#     current_temps FLOAT NOT NULL,
#     max_temps FLOAT NOT NULL,
#     min_temps FLOAT NOT NULL,
#     humidities INT NOT NULL,
#     sky_descriptions VARCHAR (255) NOT NULL,
#     visibilities FLOAT NOT NULL,
#     wind_speeds FLOAT NOT NULL,
#     sunsets_UTC TIMESTAMP NOT NULL,
#     sunrises_UTC TIMESTAMP NOT NULL,
# 	PRIMARY KEY (weather_id ), -- primary key to id each airport
# 	FOREIGN KEY (city_name_id) REFERENCES city_name(city_name_id) -- for
#  );

# %%
def store_weather_data(Weather_dataframe, connection_string):
  Weather_dataframe.to_sql('weather',
                    if_exists='append',
                    con=connection_string,
                    index=False)
